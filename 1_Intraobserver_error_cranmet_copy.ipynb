# %% [markdown]
# <a href="https://colab.research.google.com/github/cskipper07/Data-Science/blob/main/1_Intraobserver_error_cranmet_copy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Intraobserver error**
# This file compares two rounds of analysis (i.e., round1 and round2) collected by a single observer to assess intraobserver error. Some outputs have been removed to protect PII and/or the raw data.

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import scipy
import numpy as np
import seaborn as sns
# import pingouin as pt
import os

# %%
# !pip install --upgrade openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.7/dist-packages (2.5.9)
# Collecting openpyxl
#   Downloading openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 5.4 MB/s
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.1.0)
# Installing collected packages: openpyxl
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 2.5.9
#     Uninstalling openpyxl-2.5.9:
#       Successfully uninstalled openpyxl-2.5.9
# Successfully installed openpyxl-3.0.9

# %% [markdown]
# # --- Craniometrics ---

# %% [markdown]
# ### Import data

# %% [markdown]
# ### **Input data files:**
# *   *USCran_intraobserver_round1.xlsx* and *USCran_intraobserver_round2.xlsx*
# *   These files were created from the original Microsoft Access database and include all variables for the two rounds of data collection intended for intraobserver error analysis.
# *   *USCran_original.xlsx*
# *   *craniometric trait codes and names.xlsx*

# %%
cranmet_US = pd.read_excel('USCran_original.xlsx')

# %%
cranmet_US.head()

# %%
round1 = pd.read_excel('USCran_intraobserver_round1.xlsx')
round1.head(10)

# %%
round2 = pd.read_excel('USCran_intraobserver_round2.xlsx')
round2.head(10)

# %% [markdown]
# #### Explore data

# %%
round1_colnames = list(round1.columns)
for c in round1_colnames:
    print(c)
# Out:
# SkelID
# Collection
#  GOL
#  NOL
#  BNL
#  BBH
#  XCB
#  XFB
#  WFB
#  ZYB
#  AUB
#  ASB
#  BPL
#  NPH
#  NLH
#  JUB
#  NLB
#  MAB
#  MAL
#  MDH
#  OBH
#  OBB
#  DKB
#  NDS
#  WNB
#  SIS
#  ZMB
#  SSS
#  FMB
#  NAS
#  EKB
#  DKS
#  IML
#  XML
#  MLS
#  WMH
#  GLS
#  STB
#  FRC
#  FRS
#  FRF
#  PAC
#  PAS
#  PAF
#  OCC
#  OCS
#  OCF
#  FOL
#  FOB
#  NAR
#  SSR
#  PRR
#  DKR
#  ZOR
#  FMR
#  EKR
#  ZMR
#  AVR
#  BRR
#  VRR
#  LAR
#  OSR
#  BAR
#  MOW
#  UFBR
#  UFHT
#  NAA
#  PRA
#  BAA
#  NBA
#  BBA
#  BRA
#  SSA
#  NFA
#  DKA
#  NDA
#  SIA
#  FRA
#  PAA
#  OCA
#  RFA
#  RPA
#  ROA
#  BSA
#  SBA
#  SLA
#  TBA

# %% [markdown]
# ##### Drops columns

# %%
# drop 'Collection' and 'SkelID' columns in round1

round1 = round1.drop(columns=['Collection'], axis=1)
round1 = round1.drop(columns=['SkelID'], axis=1)
round1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 85 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0    GOL    3 non-null      float64
#  1    NOL    3 non-null      float64
#  2    BNL    4 non-null      int64
#  3    BBH    3 non-null      float64
#  4    XCB    4 non-null      int64
#  5    XFB    3 non-null      float64
#  6    WFB    4 non-null      int64
#  7    ZYB    4 non-null      int64
#  8    AUB    4 non-null      int64
#  9    ASB    3 non-null      float64
#  10   BPL    4 non-null      int64
#  11   NPH    4 non-null      int64
#  12   NLH    4 non-null      int64
#  13   JUB    4 non-null      int64
#  14   NLB    3 non-null      float64
#  15   MAB    2 non-null      float64
#  16   MAL    3 non-null      float64
#  17   MDH    4 non-null      int64
#  18   OBH    4 non-null      int64
#  19   OBB    4 non-null      int64
#  20   DKB    4 non-null      int64
#  21   NDS    4 non-null      int64
#  22   WNB    4 non-null      float64
#  23   SIS    4 non-null      float64
#  24   ZMB    4 non-null      int64
#  25   SSS    4 non-null      int64
#  26   FMB    4 non-null      int64
#  27   NAS    4 non-null      int64
#  28   EKB    4 non-null      int64
#  29   DKS    4 non-null      int64
#  30   IML    4 non-null      int64
#  31   XML    4 non-null      int64
#  32   MLS    4 non-null      int64
#  33   WMH    4 non-null      int64
#  34   GLS    4 non-null      int64
#  35   STB    3 non-null      float64
#  36   FRC    3 non-null      float64
#  37   FRS    3 non-null      float64
#  38   FRF    3 non-null      float64
#  39   PAC    3 non-null      float64
#  40   PAS    3 non-null      float64
#  41   PAF    3 non-null      float64
#  42   OCC    3 non-null      float64
#  43   OCS    3 non-null      float64
#  44   OCF    3 non-null      float64
#  45   FOL    4 non-null      int64
#  46   FOB    4 non-null      int64
#  47   NAR    4 non-null      int64
#  48   SSR    4 non-null      int64
#  49   PRR    4 non-null      int64
#  50   DKR    4 non-null      int64
#  51   ZOR    4 non-null      int64
#  52   FMR    4 non-null      int64
#  53   EKR    4 non-null      int64
#  54   ZMR    4 non-null      int64
#  55   AVR    2 non-null      float64
#  56   BRR    3 non-null      float64
#  57   VRR    3 non-null      float64
#  58   LAR    3 non-null      float64
#  59   OSR    4 non-null      int64
#  60   BAR    4 non-null      int64
#  61   MOW    4 non-null      int64
#  62   UFBR   4 non-null      int64
#  63   UFHT   4 non-null      int64
#  64   NAA    4 non-null      int64
#  65   PRA    4 non-null      int64
#  66   BAA    4 non-null      int64
#  67   NBA    3 non-null      float64
#  68   BBA    3 non-null      float64
#  69   BRA    3 non-null      float64
#  70   SSA    4 non-null      int64
#  71   NFA    4 non-null      int64
#  72   DKA    4 non-null      int64
#  73   NDA    4 non-null      int64
#  74   SIA    4 non-null      int64
#  75   FRA    3 non-null      float64
#  76   PAA    3 non-null      float64
#  77   OCA    3 non-null      float64
#  78   RFA    3 non-null      float64
#  79   RPA    3 non-null      float64
#  80   ROA    3 non-null      float64
#  81   BSA    4 non-null      int64
#  82   SBA    3 non-null      float64
#  83   SLA    3 non-null      float64
#  84   TBA    4 non-null      int64
# dtypes: float64(35), int64(50)
# memory usage: 2.8 KB

# %%
# remove random space before the measurement variable names

for c in round1.columns:
  print(c.strip())
  round1
  round1.rename(columns={c:c.strip()}, inplace=True)
# Out:
# GOL
# NOL
# BNL
# BBH
# XCB
# XFB
# WFB
# ZYB
# AUB
# ASB
# BPL
# NPH
# NLH
# JUB
# NLB
# MAB
# MAL
# MDH
# OBH
# OBB
# DKB
# NDS
# WNB
# SIS
# ZMB
# SSS
# FMB
# NAS
# EKB
# DKS
# IML
# XML
# MLS
# WMH
# GLS
# STB
# FRC
# FRS
# FRF
# PAC
# PAS
# PAF
# OCC
# OCS
# OCF
# FOL
# FOB
# NAR
# SSR
# PRR
# DKR
# ZOR
# FMR
# EKR
# ZMR
# AVR
# BRR
# VRR
# LAR
# OSR
# BAR
# MOW
# UFBR
# UFHT
# NAA
# PRA
# BAA
# NBA
# BBA
# BRA
# SSA
# NFA
# DKA
# NDA
# SIA
# FRA
# PAA
# OCA
# RFA
# RPA
# ROA
# BSA
# SBA
# SLA
# TBA

# %%
# drop unknown columns in round1

round1 = round1.drop(columns=['RFA'], axis=1)
round1 = round1.drop(columns=['RPA'], axis=1)
round1 = round1.drop(columns=['ROA'], axis=1)
round1 = round1.drop(columns=['BSA'], axis=1)
round1 = round1.drop(columns=['SBA'], axis=1)
round1 = round1.drop(columns=['SLA'], axis=1)
round1 = round1.drop(columns=['TBA'], axis=1)
round1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 78 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GOL     3 non-null      float64
#  1   NOL     3 non-null      float64
#  2   BNL     4 non-null      int64
#  3   BBH     3 non-null      float64
#  4   XCB     4 non-null      int64
#  5   XFB     3 non-null      float64
#  6   WFB     4 non-null      int64
#  7   ZYB     4 non-null      int64
#  8   AUB     4 non-null      int64
#  9   ASB     3 non-null      float64
#  10  BPL     4 non-null      int64
#  11  NPH     4 non-null      int64
#  12  NLH     4 non-null      int64
#  13  JUB     4 non-null      int64
#  14  NLB     3 non-null      float64
#  15  MAB     2 non-null      float64
#  16  MAL     3 non-null      float64
#  17  MDH     4 non-null      int64
#  18  OBH     4 non-null      int64
#  19  OBB     4 non-null      int64
#  20  DKB     4 non-null      int64
#  21  NDS     4 non-null      int64
#  22  WNB     4 non-null      float64
#  23  SIS     4 non-null      float64
#  24  ZMB     4 non-null      int64
#  25  SSS     4 non-null      int64
#  26  FMB     4 non-null      int64
#  27  NAS     4 non-null      int64
#  28  EKB     4 non-null      int64
#  29  DKS     4 non-null      int64
#  30  IML     4 non-null      int64
#  31  XML     4 non-null      int64
#  32  MLS     4 non-null      int64
#  33  WMH     4 non-null      int64
#  34  GLS     4 non-null      int64
#  35  STB     3 non-null      float64
#  36  FRC     3 non-null      float64
#  37  FRS     3 non-null      float64
#  38  FRF     3 non-null      float64
#  39  PAC     3 non-null      float64
#  40  PAS     3 non-null      float64
#  41  PAF     3 non-null      float64
#  42  OCC     3 non-null      float64
#  43  OCS     3 non-null      float64
#  44  OCF     3 non-null      float64
#  45  FOL     4 non-null      int64
#  46  FOB     4 non-null      int64
#  47  NAR     4 non-null      int64
#  48  SSR     4 non-null      int64
#  49  PRR     4 non-null      int64
#  50  DKR     4 non-null      int64
#  51  ZOR     4 non-null      int64
#  52  FMR     4 non-null      int64
#  53  EKR     4 non-null      int64
#  54  ZMR     4 non-null      int64
#  55  AVR     2 non-null      float64
#  56  BRR     3 non-null      float64
#  57  VRR     3 non-null      float64
#  58  LAR     3 non-null      float64
#  59  OSR     4 non-null      int64
#  60  BAR     4 non-null      int64
#  61  MOW     4 non-null      int64
#  62  UFBR    4 non-null      int64
#  63  UFHT    4 non-null      int64
#  64  NAA     4 non-null      int64
#  65  PRA     4 non-null      int64
#  66  BAA     4 non-null      int64
#  67  NBA     3 non-null      float64
#  68  BBA     3 non-null      float64
#  69  BRA     3 non-null      float64
#  70  SSA     4 non-null      int64
#  71  NFA     4 non-null      int64
#  72  DKA     4 non-null      int64
#  73  NDA     4 non-null      int64
#  74  SIA     4 non-null      int64
#  75  FRA     3 non-null      float64
#  76  PAA     3 non-null      float64
#  77  OCA     3 non-null      float64
# dtypes: float64(30), int64(48)
# memory usage: 2.6 KB

# %%
# drop 'Collection' and 'SkelID' column in round2

round2 = round2.drop(columns=['Collection'])
round2 = round2.drop(columns=['SkelID'])
round2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 85 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0    GOL    3 non-null      float64
#  1    NOL    3 non-null      float64
#  2    BNL    4 non-null      int64
#  3    BBH    3 non-null      float64
#  4    XCB    4 non-null      int64
#  5    XFB    3 non-null      float64
#  6    WFB    4 non-null      int64
#  7    ZYB    4 non-null      int64
#  8    AUB    4 non-null      int64
#  9    ASB    3 non-null      float64
#  10   BPL    4 non-null      int64
#  11   NPH    4 non-null      int64
#  12   NLH    4 non-null      int64
#  13   JUB    4 non-null      int64
#  14   NLB    3 non-null      float64
#  15   MAB    2 non-null      float64
#  16   MAL    3 non-null      float64
#  17   MDH    4 non-null      int64
#  18   OBH    4 non-null      int64
#  19   OBB    4 non-null      int64
#  20   DKB    4 non-null      int64
#  21   NDS    4 non-null      int64
#  22   WNB    4 non-null      float64
#  23   SIS    4 non-null      float64
#  24   ZMB    4 non-null      int64
#  25   SSS    4 non-null      int64
#  26   FMB    4 non-null      int64
#  27   NAS    4 non-null      int64
#  28   EKB    4 non-null      int64
#  29   DKS    4 non-null      int64
#  30   IML    4 non-null      int64
#  31   XML    4 non-null      int64
#  32   MLS    4 non-null      int64
#  33   WMH    4 non-null      int64
#  34   GLS    4 non-null      int64
#  35   STB    3 non-null      float64
#  36   FRC    3 non-null      float64
#  37   FRS    3 non-null      float64
#  38   FRF    3 non-null      float64
#  39   PAC    3 non-null      float64
#  40   PAS    3 non-null      float64
#  41   PAF    3 non-null      float64
#  42   OCC    3 non-null      float64
#  43   OCS    3 non-null      float64
#  44   OCF    3 non-null      float64
#  45   FOL    4 non-null      int64
#  46   FOB    4 non-null      int64
#  47   NAR    4 non-null      int64
#  48   SSR    4 non-null      int64
#  49   PRR    4 non-null      int64
#  50   DKR    4 non-null      int64
#  51   ZOR    4 non-null      int64
#  52   FMR    4 non-null      int64
#  53   EKR    4 non-null      int64
#  54   ZMR    4 non-null      int64
#  55   AVR    2 non-null      float64
#  56   BRR    3 non-null      float64
#  57   VRR    3 non-null      float64
#  58   LAR    3 non-null      float64
#  59   OSR    4 non-null      int64
#  60   BAR    4 non-null      int64
#  61   MOW    4 non-null      int64
#  62   UFBR   4 non-null      int64
#  63   UFHT   4 non-null      int64
#  64   NAA    4 non-null      int64
#  65   PRA    4 non-null      int64
#  66   BAA    4 non-null      int64
#  67   NBA    3 non-null      float64
#  68   BBA    3 non-null      float64
#  69   BRA    3 non-null      float64
#  70   SSA    4 non-null      int64
#  71   NFA    4 non-null      int64
#  72   DKA    4 non-null      int64
#  73   NDA    4 non-null      int64
#  74   SIA    4 non-null      int64
#  75   FRA    3 non-null      float64
#  76   PAA    3 non-null      float64
#  77   OCA    3 non-null      float64
#  78   RFA    3 non-null      float64
#  79   RPA    3 non-null      float64
#  80   ROA    3 non-null      float64
#  81   BSA    4 non-null      int64
#  82   SBA    3 non-null      float64
#  83   SLA    3 non-null      float64
#  84   TBA    4 non-null      int64
# dtypes: float64(35), int64(50)
# memory usage: 2.8 KB

# %%
# remove random space before the measurement variable names

for c in round2.columns:
  print(c.strip())
  round2
  round2.rename(columns={c:c.strip()}, inplace=True)
# Out:
# GOL
# NOL
# BNL
# BBH
# XCB
# XFB
# WFB
# ZYB
# AUB
# ASB
# BPL
# NPH
# NLH
# JUB
# NLB
# MAB
# MAL
# MDH
# OBH
# OBB
# DKB
# NDS
# WNB
# SIS
# ZMB
# SSS
# FMB
# NAS
# EKB
# DKS
# IML
# XML
# MLS
# WMH
# GLS
# STB
# FRC
# FRS
# FRF
# PAC
# PAS
# PAF
# OCC
# OCS
# OCF
# FOL
# FOB
# NAR
# SSR
# PRR
# DKR
# ZOR
# FMR
# EKR
# ZMR
# AVR
# BRR
# VRR
# LAR
# OSR
# BAR
# MOW
# UFBR
# UFHT
# NAA
# PRA
# BAA
# NBA
# BBA
# BRA
# SSA
# NFA
# DKA
# NDA
# SIA
# FRA
# PAA
# OCA
# RFA
# RPA
# ROA
# BSA
# SBA
# SLA
# TBA

# %%
# drop unknown columns in round2

round2 = round2.drop(columns=['RFA'], axis=1)
round2 = round2.drop(columns=['RPA'], axis=1)
round2 = round2.drop(columns=['ROA'], axis=1)
round2 = round2.drop(columns=['BSA'], axis=1)
round2 = round2.drop(columns=['SBA'], axis=1)
round2 = round2.drop(columns=['SLA'], axis=1)
round2 = round2.drop(columns=['TBA'], axis=1)
round2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 78 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GOL     3 non-null      float64
#  1   NOL     3 non-null      float64
#  2   BNL     4 non-null      int64
#  3   BBH     3 non-null      float64
#  4   XCB     4 non-null      int64
#  5   XFB     3 non-null      float64
#  6   WFB     4 non-null      int64
#  7   ZYB     4 non-null      int64
#  8   AUB     4 non-null      int64
#  9   ASB     3 non-null      float64
#  10  BPL     4 non-null      int64
#  11  NPH     4 non-null      int64
#  12  NLH     4 non-null      int64
#  13  JUB     4 non-null      int64
#  14  NLB     3 non-null      float64
#  15  MAB     2 non-null      float64
#  16  MAL     3 non-null      float64
#  17  MDH     4 non-null      int64
#  18  OBH     4 non-null      int64
#  19  OBB     4 non-null      int64
#  20  DKB     4 non-null      int64
#  21  NDS     4 non-null      int64
#  22  WNB     4 non-null      float64
#  23  SIS     4 non-null      float64
#  24  ZMB     4 non-null      int64
#  25  SSS     4 non-null      int64
#  26  FMB     4 non-null      int64
#  27  NAS     4 non-null      int64
#  28  EKB     4 non-null      int64
#  29  DKS     4 non-null      int64
#  30  IML     4 non-null      int64
#  31  XML     4 non-null      int64
#  32  MLS     4 non-null      int64
#  33  WMH     4 non-null      int64
#  34  GLS     4 non-null      int64
#  35  STB     3 non-null      float64
#  36  FRC     3 non-null      float64
#  37  FRS     3 non-null      float64
#  38  FRF     3 non-null      float64
#  39  PAC     3 non-null      float64
#  40  PAS     3 non-null      float64
#  41  PAF     3 non-null      float64
#  42  OCC     3 non-null      float64
#  43  OCS     3 non-null      float64
#  44  OCF     3 non-null      float64
#  45  FOL     4 non-null      int64
#  46  FOB     4 non-null      int64
#  47  NAR     4 non-null      int64
#  48  SSR     4 non-null      int64
#  49  PRR     4 non-null      int64
#  50  DKR     4 non-null      int64
#  51  ZOR     4 non-null      int64
#  52  FMR     4 non-null      int64
#  53  EKR     4 non-null      int64
#  54  ZMR     4 non-null      int64
#  55  AVR     2 non-null      float64
#  56  BRR     3 non-null      float64
#  57  VRR     3 non-null      float64
#  58  LAR     3 non-null      float64
#  59  OSR     4 non-null      int64
#  60  BAR     4 non-null      int64
#  61  MOW     4 non-null      int64
#  62  UFBR    4 non-null      int64
#  63  UFHT    4 non-null      int64
#  64  NAA     4 non-null      int64
#  65  PRA     4 non-null      int64
#  66  BAA     4 non-null      int64
#  67  NBA     3 non-null      float64
#  68  BBA     3 non-null      float64
#  69  BRA     3 non-null      float64
#  70  SSA     4 non-null      int64
#  71  NFA     4 non-null      int64
#  72  DKA     4 non-null      int64
#  73  NDA     4 non-null      int64
#  74  SIA     4 non-null      int64
#  75  FRA     3 non-null      float64
#  76  PAA     3 non-null      float64
#  77  OCA     3 non-null      float64
# dtypes: float64(30), int64(48)
# memory usage: 2.6 KB

# %%
round2.head()

# %%
round1.head()

# %% [markdown]
# ---

# %% [markdown]
# ## Remove NAs with For Loop
# #### 1) Check dataframe1 for NaNs. For any NaNs in df1, check against corresponding cells in dataframe2. If df2 also has NaN in that cell, set both cells (in df1 and df2) to 0.
# #### 2) Find all NaNs in dataframe 2 and substitute with corresponding values from df1. (No need to check df1 for NaNs since Step 1 already removed all NaNs from df1).

# %%
def remove_nan(round1, round2):
    column1 = list(round1.columns)
    column2 = list(round2.columns)
    for i in range(len(column1)):
        na_indx1 = list(np.where(round1[column1[i]].isna()))
        na_indx2 = list(np.where(round2[column2[i]].isna()))
        print(na_indx1)
        for j in na_indx1[0]:
            if not (np.isnan(round2[column2[i]][j])):# != 'nan' :
                round1[column1[i]][j] = round2[column2[i]][j]
                #print(type(round2[column[i]][j]))
                #input(round1[column[i]][j])
                #print("I am here")
            else:
                round2[column2[i]][j] = 0
                round1[column1[i]][j] = 0
                #input(round1[column][j])
        for j in na_indx2[0]:
                round2[column2[i]][j] = round1[column1[i]][j]
    return round1, round2
        #indx1 = set()
        #print(type(na_indx1))
        #indx1 = set(na_indx1)
        #indx2 = set((na_indx2))
        #print(round1[column[i]][na_indx1[0][1]])
        #print(na_indx1[0])
        #print(round1[column[i]].isnull())
        #print(round1[column[i]], round2[column[i]])

# %%
remove_nan(round1, round2)
# Out:
# [array([0])]
# [array([0])]
# [array([], dtype=int64)]
# [array([0])]
# [array([], dtype=int64)]
# [array([0])]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([0])]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([2])]
# [array([2, 3])]
# [array([2])]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([0])]
# [array([0])]
# [array([0])]
# [array([0])]
# [array([0])]
# [array([0])]
# [array([0])]
# [array([0])]
# [array([0])]
# [array([0])]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([2, 3])]
# [array([0])]
# [array([0])]
# [array([0])]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([0])]
# [array([0])]
# [array([0])]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([0])]
# [array([0])]
# [array([0])]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (     GOL    NOL  BNL    BBH  XCB    XFB  ...  DKA  NDA  SIA    FRA    PAA    OCA
#  0    0.0    0.0  108    0.0  156    0.0  ...  147   93  106    0.0    0.0    0.0
#  1  180.0  175.0   98  141.0  148  122.0  ...  148  101   99  131.0  130.0  120.0
#  2  171.0  168.0   96  136.0  152  122.0  ...  141   97  128  124.0  126.0  129.0
#  3  183.0  180.0   96  131.0  139  117.0  ...  158   90   91  127.0  144.0  112.0
#
#  [4 rows x 78 columns],
#       GOL    NOL  BNL    BBH  XCB    XFB  ...  DKA  NDA  SIA    FRA    PAA    OCA
#  0    0.0    0.0  108    0.0  156    0.0  ...  147   93  108    0.0    0.0    0.0
#  1  179.0  175.0   98  141.0  148  122.0  ...  146  101  113  129.0  130.0  122.0
#  2  170.0  168.0   96  136.0  152  122.0  ...  141   97  120  124.0  128.0  127.0
#  3  184.0  180.0   95  131.0  139  117.0  ...  158   90   95  126.0  142.0  112.0
#
#  [4 rows x 78 columns])

# %%
r1 = pd.DataFrame()
r2 = pd.DataFrame()

# %%
#print(round2[column[1]][j])
r1, r2 = remove_nan(round1, round2)    # prints the location (indices) of all NaNs in the r1 and r2 DFs
# Out:
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]
# [array([], dtype=int64)]

# %%
r2.head()

# %%
round1.head()

# %%
round2.head()

# %% [markdown]
# ## TEM Intraobserver Error

# %%
column_names = ['Trait Code', 'n pairs', 'TEM', 'Relative TEM']       # since NaNs were replace with zeros, n=45 for every variable
TEMoutput = pd.DataFrame(columns = column_names)
column1 = list(round1.columns)
column2 = list(round2.columns)
for i in range(len(column1)):
        ob1 = round1[column1[i]]
        ob2 = round2[column2[i]]
        y = (ob1 - ob2)**2
        TEM = (sum(y))/(2*(len(y)))
        z1 = np.mean(ob1)
        z2 = np.mean(ob2)
        VAV = np.mean([z1 , z2])
        relTEM=(TEM/VAV)*100
        print(column2[i], '\t', len(ob1), '\t', round(TEM, 5), '\t', round(relTEM, 5))
        df2 = {'Trait Code': column2[i], 'n pairs': len(ob1), 'TEM': round(TEM,5), 'Relative TEM': round(relTEM,5)}
        TEMoutput.loc[i] = [ column2[i],  len(ob1), round(TEM,5), round(relTEM,5)]
# Out:
# GOL 	 4 	 0.375 	 0.28116
# NOL 	 4 	 0.0 	 0.0
# BNL 	 4 	 0.125 	 0.12579
# BBH 	 4 	 0.0 	 0.0
# XCB 	 4 	 0.0 	 0.0
# XFB 	 4 	 0.0 	 0.0
# WFB 	 4 	 0.25 	 0.25974
# ZYB 	 4 	 0.0 	 0.0
# AUB 	 4 	 21.375 	 16.33238
# ASB 	 4 	 0.125 	 0.14728
# BPL 	 4 	 0.125 	 0.13245
# NPH 	 4 	 0.25 	 0.37037
# NLH 	 4 	 0.125 	 0.24213
# JUB 	 4 	 0.25 	 0.21413
# NLB 	 4 	 0.125 	 0.62112
# MAB 	 4 	 0.125 	 0.35587
# MAL 	 4 	 0.625 	 1.47493
# MDH 	 4 	 0.875 	 2.5641
# OBH 	 4 	 0.0 	 0.0
# OBB 	 4 	 0.125 	 0.28818
# DKB 	 4 	 0.0 	 0.0
# NDS 	 4 	 0.0 	 0.0
# WNB 	 4 	 0.02 	 0.3252
# SIS 	 4 	 0.0275 	 1.20879
# ZMB 	 4 	 0.125 	 0.12837
# SSS 	 4 	 0.0 	 0.0
# FMB 	 4 	 0.125 	 0.12392
# NAS 	 4 	 0.25 	 1.5625
# EKB 	 4 	 0.125 	 0.12361
# DKS 	 4 	 0.125 	 1.05263
# IML 	 4 	 0.25 	 0.74074
# XML 	 4 	 0.625 	 1.14943
# MLS 	 4 	 0.125 	 0.95238
# WMH 	 4 	 0.125 	 0.54054
# GLS 	 4 	 0.125 	 2.32558
# STB 	 4 	 0.125 	 0.14599
# FRC 	 4 	 0.0 	 0.0
# FRS 	 4 	 0.125 	 0.5848
# FRF 	 4 	 3.375 	 8.51735
# PAC 	 4 	 0.125 	 0.15175
# PAS 	 4 	 0.375 	 2.0979
# PAF 	 4 	 6.375 	 15.13353
# OCC 	 4 	 0.25 	 0.32895
# OCS 	 4 	 0.25 	 1.16279
# OCF 	 4 	 2.25 	 5.29412
# FOL 	 4 	 0.125 	 0.34602
# FOB 	 4 	 0.25 	 0.7874
# NAR 	 4 	 2.25 	 2.41935
# SSR 	 4 	 0.125 	 0.13793
# PRR 	 4 	 0.375 	 0.38314
# DKR 	 4 	 0.625 	 0.75643
# ZOR 	 4 	 0.125 	 0.15748
# FMR 	 4 	 0.375 	 0.48309
# EKR 	 4 	 0.375 	 0.51813
# ZMR 	 4 	 0.75 	 1.07914
# AVR 	 4 	 0.125 	 0.29851
# BRR 	 4 	 0.125 	 0.13495
# VRR 	 4 	 0.125 	 0.1328
# LAR 	 4 	 0.125 	 0.15601
# OSR 	 4 	 1.25 	 3.0303
# BAR 	 4 	 1.5 	 10.52632
# MOW 	 4 	 0.125 	 0.23529
# UFBR 	 4 	 0.0 	 0.0
# UFHT 	 4 	 0.25 	 0.35211
# NAA 	 4 	 0.375 	 0.57361
# PRA 	 4 	 0.25 	 0.33557
# BAA 	 4 	 0.25 	 0.62112
# NBA 	 4 	 0.125 	 0.20964
# BBA 	 4 	 0.0 	 0.0
# BRA 	 4 	 0.125 	 0.37736
# SSA 	 4 	 0.125 	 0.09479
# NFA 	 4 	 1.0 	 0.68966
# DKA 	 4 	 0.5 	 0.33727
# NDA 	 4 	 0.0 	 0.0
# SIA 	 4 	 35.0 	 32.55814
# FRA 	 4 	 0.625 	 0.65703
# PAA 	 4 	 1.0 	 1.0
# OCA 	 4 	 1.0 	 1.10803

# %%
TEMoutput.head(20)
# Out:
#    Trait Code n pairs     TEM  Relative TEM
# 0         GOL       4   0.375       0.28116
# 1         NOL       4   0.000       0.00000
# 2         BNL       4   0.125       0.12579
# 3         BBH       4   0.000       0.00000
# 4         XCB       4   0.000       0.00000
# 5         XFB       4   0.000       0.00000
# 6         WFB       4   0.250       0.25974
# 7         ZYB       4   0.000       0.00000
# 8         AUB       4  21.375      16.33238
# 9         ASB       4   0.125       0.14728
# 10        BPL       4   0.125       0.13245
# 11        NPH       4   0.250       0.37037
# 12        NLH       4   0.125       0.24213
# 13        JUB       4   0.250       0.21413
# 14        NLB       4   0.125       0.62112
# 15        MAB       4   0.125       0.35587
# 16        MAL       4   0.625       1.47493
# 17        MDH       4   0.875       2.56410
# 18        OBH       4   0.000       0.00000
# 19        OBB       4   0.125       0.28818

# %%
TEMoutput_sorted = TEMoutput.sort_values(by='Relative TEM', ascending=False)

# %%
TEMoutput_sorted.head(15)
# Out:
#    Trait Code n pairs      TEM  Relative TEM
# 74        SIA       4  35.0000      32.55814
# 8         AUB       4  21.3750      16.33238
# 41        PAF       4   6.3750      15.13353
# 60        BAR       4   1.5000      10.52632
# 38        FRF       4   3.3750       8.51735
# 44        OCF       4   2.2500       5.29412
# 59        OSR       4   1.2500       3.03030
# 17        MDH       4   0.8750       2.56410
# 47        NAR       4   2.2500       2.41935
# 34        GLS       4   0.1250       2.32558
# 40        PAS       4   0.3750       2.09790
# 27        NAS       4   0.2500       1.56250
# 16        MAL       4   0.6250       1.47493
# 23        SIS       4   0.0275       1.20879
# 43        OCS       4   0.2500       1.16279

# %%
# identify variables with a Relative TEM greater than 5 to remove these columns

TEMoutput_sorted.loc[TEMoutput_sorted['Relative TEM'] > 5]
# Out:
#    Trait Code n pairs     TEM  Relative TEM
# 74        SIA       4  35.000      32.55814
# 8         AUB       4  21.375      16.33238
# 41        PAF       4   6.375      15.13353
# 60        BAR       4   1.500      10.52632
# 38        FRF       4   3.375       8.51735
# 44        OCF       4   2.250       5.29412

# %% [markdown]
# ### List of traits to remove

# %%
remove_traits = TEMoutput_sorted.loc[TEMoutput['Relative TEM'] > 5]

# %% [markdown]
# ### Add trait codes and names to TEMoutput file

# %%
codes_names = pd.read_excel('craniometric trait codes and names.xlsx')
codes_names.head()
# Out:
#   Trait Code                 Trait Name
# 0        GOL  Glabello-occipital length
# 1        NOL     Nasio-occipital length
# 2        BNL       Basion-nasion length
# 3        BBH       Basion-bregma height
# 4        XCB    Maximum cranial breadth

# %%
# remove random space before the measurement variable names

for c in codes_names.columns:
  print(c.strip())
  codes_names
  codes_names.rename(columns={c:c.strip()}, inplace=True)
# Out:
# Trait Code
# Trait Name

# %%
TEMresults_named = pd.merge(TEMoutput, codes_names, on='Trait Code')
TEMresults_named.head()
# Out:
# Empty DataFrame
# Columns: [Trait Code, n pairs, TEM, Relative TEM, Trait Name]
# Index: []

# %%
TEMresults_named.tail()
# Out:
# Empty DataFrame
# Columns: [Trait Code, n pairs, TEM, Relative TEM, Trait Name]
# Index: []

# %%
from google.colab import  drive
drive.mount('/drive')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
TEMresults_named.to_csv('/drive/My Drive/Colab Notebooks/Pre-statistical treatments/1_Observer error/cranmet_intraobserver_TEM_results.csv')

# %% [markdown]
# ---

# %% [markdown]
# ## Merge craniometric dfs with demographics

# %% [markdown]
# #### US data

# %%
cranmet_US = pd.read_excel('USCran_for_analysis.xlsx')
cranmet_US.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 87 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SkelID      48 non-null     int64
#  1   Collection  48 non-null     object
#  2    GOL        44 non-null     float64
#  3    NOL        44 non-null     float64
#  4    BNL        47 non-null     float64
#  5    BBH        46 non-null     float64
#  6    XCB        48 non-null     int64
#  7    XFB        47 non-null     float64
#  8    WFB        48 non-null     int64
#  9    ZYB        48 non-null     int64
#  10   AUB        48 non-null     int64
#  11   ASB        41 non-null     float64
#  12   BPL        42 non-null     float64
#  13   NPH        41 non-null     float64
#  14   NLH        47 non-null     float64
#  15   JUB        48 non-null     int64
#  16   NLB        45 non-null     float64
#  17   MAB        26 non-null     float64
#  18   MAL        41 non-null     float64
#  19   MDH        48 non-null     int64
#  20   OBH        47 non-null     float64
#  21   OBB        45 non-null     float64
#  22   DKB        45 non-null     float64
#  23   NDS        43 non-null     float64
#  24   WNB        46 non-null     float64
#  25   SIS        44 non-null     float64
#  26   ZMB        47 non-null     float64
#  27   SSS        46 non-null     float64
#  28   FMB        48 non-null     int64
#  29   NAS        47 non-null     float64
#  30   EKB        47 non-null     float64
#  31   DKS        45 non-null     float64
#  32   IML        48 non-null     int64
#  33   XML        48 non-null     int64
#  34   MLS        46 non-null     float64
#  35   WMH        48 non-null     int64
#  36   GLS        47 non-null     float64
#  37   STB        47 non-null     float64
#  38   FRC        45 non-null     float64
#  39   FRS        45 non-null     float64
#  40   FRF        45 non-null     float64
#  41   PAC        45 non-null     float64
#  42   PAS        45 non-null     float64
#  43   PAF        45 non-null     float64
#  44   OCC        45 non-null     float64
#  45   OCS        45 non-null     float64
#  46   OCF        45 non-null     float64
#  47   FOL        48 non-null     int64
#  48   FOB        48 non-null     int64
#  49   NAR        47 non-null     float64
#  50   SSR        47 non-null     float64
#  51   PRR        42 non-null     float64
#  52   DKR        45 non-null     float64
#  53   ZOR        48 non-null     int64
#  54   FMR        48 non-null     int64
#  55   EKR        48 non-null     int64
#  56   ZMR        48 non-null     int64
#  57   AVR        33 non-null     float64
#  58   BRR        46 non-null     float64
#  59   VRR        45 non-null     float64
#  60   LAR        45 non-null     float64
#  61   OSR        48 non-null     int64
#  62   BAR        48 non-null     int64
#  63   MOW        41 non-null     float64
#  64   UFBR       48 non-null     int64
#  65   UFHT       38 non-null     float64
#  66   NAA        42 non-null     float64
#  67   PRA        42 non-null     float64
#  68   BAA        42 non-null     float64
#  69   NBA        45 non-null     float64
#  70   BBA        45 non-null     float64
#  71   BRA        45 non-null     float64
#  72   SSA        46 non-null     float64
#  73   NFA        47 non-null     float64
#  74   DKA        45 non-null     float64
#  75   NDA        43 non-null     float64
#  76   SIA        44 non-null     float64
#  77   FRA        45 non-null     float64
#  78   PAA        45 non-null     float64
#  79   OCA        45 non-null     float64
#  80   RFA        45 non-null     float64
#  81   RPA        45 non-null     float64
#  82   ROA        45 non-null     float64
#  83   BSA        43 non-null     float64
#  84   SBA        44 non-null     float64
#  85   SLA        45 non-null     float64
#  86   TBA        48 non-null     int64
# dtypes: float64(65), int64(21), object(1)
# memory usage: 32.8+ KB

# %%
cranmet_US_demographics = pd.read_excel('US demographics.xlsx')
cranmet_US_demographics.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SkelID       241 non-null    int64
#  1   Sex          241 non-null    object
#  2   Age          241 non-null    int64
#  3   Population   241 non-null    object
#  4   Population2  44 non-null     object
#  5   Population3  13 non-null     object
#  6   Population4  1 non-null      object
# dtypes: int64(2), object(5)
# memory usage: 13.3+ KB

# %%
cranmet_US_merged = pd.merge(cranmet_US, cranmet_US_demographics, on='SkelID')

# %%
cranmet_US_merged.head(10)

# %%
from google.colab import  drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
cranmet_US_merged.to_csv('/drive/My Drive/Colab Notebooks/Pre-statistical treatments/cranmet_US_merged.csv')

# %%
del cranmet_US_merged['Population']
del cranmet_US_merged['Population2']
del cranmet_US_merged['Population3']
del cranmet_US_merged['Population4']

# %% [markdown]
# #### Japan data

# %%
cranmet_Japan = pd.read_excel('JapanCran_for_analysis.xlsx')

# %%
cranmet_Japan.head()

# %%
cranmet_Japan_demographics = pd.read_excel('Japan_demographics.xlsx')
cranmet_Japan_demographics.head()

# %%
del cranmet_Japan_demographics['Notes']
del cranmet_Japan_demographics['Date']
del cranmet_Japan_demographics['DOB']
del cranmet_Japan_demographics['DOD']
del cranmet_Japan_demographics['Year of death']
del cranmet_Japan_demographics['Year/ind# of death (Japan)']

# %%
cranmet_Japan_demographics.head()

# %%
cranmet_Japan_merged = pd.merge(cranmet_Japan, cranmet_Japan_demographics, on='SkelID')

# %%
cranmet_Japan_merged.head()

# %%
cranmet_Japan_merged.to_csv('/drive/My Drive/Colab Notebooks/Pre-statistical treatments/cranmet_Japan_merged.csv')

# %% [markdown]
# ### Merge US and Japan craniometrics

# %%
cranmet_Japan_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 0 to 33
# Data columns (total 89 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SkelID      34 non-null     int64
#  1   Collection  34 non-null     object
#  2    GOL        34 non-null     int64
#  3    NOL        34 non-null     int64
#  4    BNL        34 non-null     int64
#  5    BBH        34 non-null     int64
#  6    XCB        34 non-null     int64
#  7    XFB        34 non-null     int64
#  8    WFB        34 non-null     int64
#  9    ZYB        34 non-null     int64
#  10   AUB        34 non-null     int64
#  11   ASB        32 non-null     float64
#  12   BPL        33 non-null     float64
#  13   NPH        33 non-null     float64
#  14   NLH        34 non-null     int64
#  15   JUB        34 non-null     int64
#  16   NLB        34 non-null     int64
#  17   MAB        34 non-null     int64
#  18   MAL        33 non-null     float64
#  19   MDH        34 non-null     int64
#  20   OBH        34 non-null     int64
#  21   OBB        34 non-null     int64
#  22   DKB        34 non-null     int64
#  23   NDS        29 non-null     float64
#  24   WNB        34 non-null     float64
#  25   SIS        29 non-null     float64
#  26   ZMB        33 non-null     float64
#  27   SSS        33 non-null     float64
#  28   FMB        34 non-null     int64
#  29   NAS        34 non-null     int64
#  30   EKB        34 non-null     int64
#  31   DKS        34 non-null     int64
#  32   IML        33 non-null     float64
#  33   XML        33 non-null     float64
#  34   MLS        33 non-null     float64
#  35   WMH        34 non-null     int64
#  36   GLS        34 non-null     int64
#  37   STB        34 non-null     int64
#  38   FRC        34 non-null     int64
#  39   FRS        34 non-null     int64
#  40   FRF        34 non-null     int64
#  41   PAC        34 non-null     int64
#  42   PAS        34 non-null     int64
#  43   PAF        34 non-null     int64
#  44   OCC        34 non-null     int64
#  45   OCS        34 non-null     int64
#  46   OCF        34 non-null     int64
#  47   FOL        34 non-null     int64
#  48   FOB        34 non-null     int64
#  49   NAR        34 non-null     int64
#  50   SSR        34 non-null     int64
#  51   PRR        33 non-null     float64
#  52   DKR        34 non-null     int64
#  53   ZOR        33 non-null     float64
#  54   FMR        34 non-null     int64
#  55   EKR        34 non-null     int64
#  56   ZMR        33 non-null     float64
#  57   AVR        34 non-null     int64
#  58   BRR        34 non-null     int64
#  59   VRR        34 non-null     int64
#  60   LAR        34 non-null     int64
#  61   OSR        34 non-null     int64
#  62   BAR        34 non-null     int64
#  63   MOW        33 non-null     float64
#  64   UFBR       34 non-null     int64
#  65   UFHT       23 non-null     float64
#  66   NAA        33 non-null     float64
#  67   PRA        33 non-null     float64
#  68   BAA        33 non-null     float64
#  69   NBA        34 non-null     int64
#  70   BBA        34 non-null     int64
#  71   BRA        34 non-null     int64
#  72   SSA        33 non-null     float64
#  73   NFA        34 non-null     int64
#  74   DKA        34 non-null     int64
#  75   NDA        29 non-null     float64
#  76   SIA        29 non-null     float64
#  77   FRA        34 non-null     int64
#  78   PAA        34 non-null     int64
#  79   OCA        34 non-null     int64
#  80   RFA        34 non-null     int64
#  81   RPA        34 non-null     int64
#  82   ROA        34 non-null     int64
#  83   BSA        33 non-null     float64
#  84   SBA        34 non-null     int64
#  85   SLA        34 non-null     int64
#  86   TBA        34 non-null     int64
#  87  Sex         34 non-null     object
#  88  Age         34 non-null     int64
# dtypes: float64(24), int64(63), object(2)
# memory usage: 23.9+ KB

# %%
cranmet_US_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 0 to 47
# Data columns (total 89 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SkelID      48 non-null     int64
#  1   Collection  48 non-null     object
#  2    GOL        44 non-null     float64
#  3    NOL        44 non-null     float64
#  4    BNL        47 non-null     float64
#  5    BBH        46 non-null     float64
#  6    XCB        48 non-null     int64
#  7    XFB        47 non-null     float64
#  8    WFB        48 non-null     int64
#  9    ZYB        48 non-null     int64
#  10   AUB        48 non-null     int64
#  11   ASB        41 non-null     float64
#  12   BPL        42 non-null     float64
#  13   NPH        41 non-null     float64
#  14   NLH        47 non-null     float64
#  15   JUB        48 non-null     int64
#  16   NLB        45 non-null     float64
#  17   MAB        26 non-null     float64
#  18   MAL        41 non-null     float64
#  19   MDH        48 non-null     int64
#  20   OBH        47 non-null     float64
#  21   OBB        45 non-null     float64
#  22   DKB        45 non-null     float64
#  23   NDS        43 non-null     float64
#  24   WNB        46 non-null     float64
#  25   SIS        44 non-null     float64
#  26   ZMB        47 non-null     float64
#  27   SSS        46 non-null     float64
#  28   FMB        48 non-null     int64
#  29   NAS        47 non-null     float64
#  30   EKB        47 non-null     float64
#  31   DKS        45 non-null     float64
#  32   IML        48 non-null     int64
#  33   XML        48 non-null     int64
#  34   MLS        46 non-null     float64
#  35   WMH        48 non-null     int64
#  36   GLS        47 non-null     float64
#  37   STB        47 non-null     float64
#  38   FRC        45 non-null     float64
#  39   FRS        45 non-null     float64
#  40   FRF        45 non-null     float64
#  41   PAC        45 non-null     float64
#  42   PAS        45 non-null     float64
#  43   PAF        45 non-null     float64
#  44   OCC        45 non-null     float64
#  45   OCS        45 non-null     float64
#  46   OCF        45 non-null     float64
#  47   FOL        48 non-null     int64
#  48   FOB        48 non-null     int64
#  49   NAR        47 non-null     float64
#  50   SSR        47 non-null     float64
#  51   PRR        42 non-null     float64
#  52   DKR        45 non-null     float64
#  53   ZOR        48 non-null     int64
#  54   FMR        48 non-null     int64
#  55   EKR        48 non-null     int64
#  56   ZMR        48 non-null     int64
#  57   AVR        33 non-null     float64
#  58   BRR        46 non-null     float64
#  59   VRR        45 non-null     float64
#  60   LAR        45 non-null     float64
#  61   OSR        48 non-null     int64
#  62   BAR        48 non-null     int64
#  63   MOW        41 non-null     float64
#  64   UFBR       48 non-null     int64
#  65   UFHT       38 non-null     float64
#  66   NAA        42 non-null     float64
#  67   PRA        42 non-null     float64
#  68   BAA        42 non-null     float64
#  69   NBA        45 non-null     float64
#  70   BBA        45 non-null     float64
#  71   BRA        45 non-null     float64
#  72   SSA        46 non-null     float64
#  73   NFA        47 non-null     float64
#  74   DKA        45 non-null     float64
#  75   NDA        43 non-null     float64
#  76   SIA        44 non-null     float64
#  77   FRA        45 non-null     float64
#  78   PAA        45 non-null     float64
#  79   OCA        45 non-null     float64
#  80   RFA        45 non-null     float64
#  81   RPA        45 non-null     float64
#  82   ROA        45 non-null     float64
#  83   BSA        43 non-null     float64
#  84   SBA        44 non-null     float64
#  85   SLA        45 non-null     float64
#  86   TBA        48 non-null     int64
#  87  Sex         48 non-null     object
#  88  Age         48 non-null     int64
# dtypes: float64(65), int64(22), object(2)
# memory usage: 33.8+ KB

# %%
cranmet_merged = cranmet_US_merged.append(cranmet_Japan_merged)

# %%
cranmet_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82 entries, 0 to 33
# Data columns (total 89 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SkelID      82 non-null     int64
#  1   Collection  82 non-null     object
#  2    GOL        78 non-null     float64
#  3    NOL        78 non-null     float64
#  4    BNL        81 non-null     float64
#  5    BBH        80 non-null     float64
#  6    XCB        82 non-null     int64
#  7    XFB        81 non-null     float64
#  8    WFB        82 non-null     int64
#  9    ZYB        82 non-null     int64
#  10   AUB        82 non-null     int64
#  11   ASB        73 non-null     float64
#  12   BPL        75 non-null     float64
#  13   NPH        74 non-null     float64
#  14   NLH        81 non-null     float64
#  15   JUB        82 non-null     int64
#  16   NLB        79 non-null     float64
#  17   MAB        60 non-null     float64
#  18   MAL        74 non-null     float64
#  19   MDH        82 non-null     int64
#  20   OBH        81 non-null     float64
#  21   OBB        79 non-null     float64
#  22   DKB        79 non-null     float64
#  23   NDS        72 non-null     float64
#  24   WNB        80 non-null     float64
#  25   SIS        73 non-null     float64
#  26   ZMB        80 non-null     float64
#  27   SSS        79 non-null     float64
#  28   FMB        82 non-null     int64
#  29   NAS        81 non-null     float64
#  30   EKB        81 non-null     float64
#  31   DKS        79 non-null     float64
#  32   IML        81 non-null     float64
#  33   XML        81 non-null     float64
#  34   MLS        79 non-null     float64
#  35   WMH        82 non-null     int64
#  36   GLS        81 non-null     float64
#  37   STB        81 non-null     float64
#  38   FRC        79 non-null     float64
#  39   FRS        79 non-null     float64
#  40   FRF        79 non-null     float64
#  41   PAC        79 non-null     float64
#  42   PAS        79 non-null     float64
#  43   PAF        79 non-null     float64
#  44   OCC        79 non-null     float64
#  45   OCS        79 non-null     float64
#  46   OCF        79 non-null     float64
#  47   FOL        82 non-null     int64
#  48   FOB        82 non-null     int64
#  49   NAR        81 non-null     float64
#  50   SSR        81 non-null     float64
#  51   PRR        75 non-null     float64
#  52   DKR        79 non-null     float64
#  53   ZOR        81 non-null     float64
#  54   FMR        82 non-null     int64
#  55   EKR        82 non-null     int64
#  56   ZMR        81 non-null     float64
#  57   AVR        67 non-null     float64
#  58   BRR        80 non-null     float64
#  59   VRR        79 non-null     float64
#  60   LAR        79 non-null     float64
#  61   OSR        82 non-null     int64
#  62   BAR        82 non-null     int64
#  63   MOW        74 non-null     float64
#  64   UFBR       82 non-null     int64
#  65   UFHT       61 non-null     float64
#  66   NAA        75 non-null     float64
#  67   PRA        75 non-null     float64
#  68   BAA        75 non-null     float64
#  69   NBA        79 non-null     float64
#  70   BBA        79 non-null     float64
#  71   BRA        79 non-null     float64
#  72   SSA        79 non-null     float64
#  73   NFA        81 non-null     float64
#  74   DKA        79 non-null     float64
#  75   NDA        72 non-null     float64
#  76   SIA        73 non-null     float64
#  77   FRA        79 non-null     float64
#  78   PAA        79 non-null     float64
#  79   OCA        79 non-null     float64
#  80   RFA        79 non-null     float64
#  81   RPA        79 non-null     float64
#  82   ROA        79 non-null     float64
#  83   BSA        76 non-null     float64
#  84   SBA        78 non-null     float64
#  85   SLA        79 non-null     float64
#  86   TBA        82 non-null     int64
#  87  Sex         82 non-null     object
#  88  Age         82 non-null     int64
# dtypes: float64(69), int64(18), object(2)
# memory usage: 57.7+ KB

# %%
cranmet_merged.head()

# %%
cranmet_merged.tail()

# %% [markdown]
# ##### Remove random space before the measurement variable names

# %%
cranmet_merged.columns
# Out:
# Index(['SkelID', 'Collection', ' GOL', ' NOL', ' BNL', ' BBH', ' XCB', ' XFB',
#        ' WFB', ' ZYB', ' ASB', ' BPL', ' NPH', ' NLH', ' JUB', ' NLB', ' MAB',
#        ' MAL', ' MDH', ' OBH', ' OBB', ' DKB', ' NDS', ' WNB', ' SIS', ' ZMB',
#        ' SSS', ' FMB', ' NAS', ' EKB', ' DKS', ' IML', ' XML', ' MLS', ' WMH',
#        ' GLS', ' STB', ' FRC', ' FRS', ' FRF', ' PAC', ' PAS', ' PAF', ' OCC',
#        ' OCS', ' OCF', ' FOL', ' FOB', ' NAR', ' SSR', ' PRR', ' DKR', ' ZOR',
#        ' FMR', ' EKR', ' ZMR', ' AVR', ' BRR', ' VRR', ' LAR', ' OSR', ' BAR',
#        ' MOW', ' UFBR', ' UFHT', ' NAA', ' PRA', ' BAA', ' NBA', ' BBA',
#        ' BRA', ' SSA', ' NFA', ' DKA', ' NDA', ' SIA', ' FRA', ' PAA', ' OCA',
#        ' RFA', ' RPA', ' ROA', ' BSA', ' SBA', ' SLA', ' TBA', 'Sex', 'Age'],
#       dtype='object')

# %%
# remove random space before the measurement variable names

for c in cranmet_merged.columns:
  print(c.strip())
  cranmet_merged
  cranmet_merged.rename(columns={c:c.strip()}, inplace=True)
# Out:
# SkelID
# Collection
# GOL
# NOL
# BNL
# BBH
# XCB
# XFB
# WFB
# ZYB
# AUB
# ASB
# BPL
# NPH
# NLH
# JUB
# NLB
# MAB
# MAL
# MDH
# OBH
# OBB
# DKB
# NDS
# WNB
# SIS
# ZMB
# SSS
# FMB
# NAS
# EKB
# DKS
# IML
# XML
# MLS
# WMH
# GLS
# STB
# FRC
# FRS
# FRF
# PAC
# PAS
# PAF
# OCC
# OCS
# OCF
# FOL
# FOB
# NAR
# SSR
# PRR
# DKR
# ZOR
# FMR
# EKR
# ZMR
# AVR
# BRR
# VRR
# LAR
# OSR
# BAR
# MOW
# UFBR
# UFHT
# NAA
# PRA
# BAA
# NBA
# BBA
# BRA
# SSA
# NFA
# DKA
# NDA
# SIA
# FRA
# PAA
# OCA
# RFA
# RPA
# ROA
# BSA
# SBA
# SLA
# TBA
# Sex
# Age

# %%
cranmet_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82 entries, 0 to 33
# Data columns (total 89 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SkelID      82 non-null     int64
#  1   Collection  82 non-null     object
#  2   GOL         78 non-null     float64
#  3   NOL         78 non-null     float64
#  4   BNL         81 non-null     float64
#  5   BBH         80 non-null     float64
#  6   XCB         82 non-null     int64
#  7   XFB         81 non-null     float64
#  8   WFB         82 non-null     int64
#  9   ZYB         82 non-null     int64
#  10  AUB         82 non-null     int64
#  11  ASB         73 non-null     float64
#  12  BPL         75 non-null     float64
#  13  NPH         74 non-null     float64
#  14  NLH         81 non-null     float64
#  15  JUB         82 non-null     int64
#  16  NLB         79 non-null     float64
#  17  MAB         60 non-null     float64
#  18  MAL         74 non-null     float64
#  19  MDH         82 non-null     int64
#  20  OBH         81 non-null     float64
#  21  OBB         79 non-null     float64
#  22  DKB         79 non-null     float64
#  23  NDS         72 non-null     float64
#  24  WNB         80 non-null     float64
#  25  SIS         73 non-null     float64
#  26  ZMB         80 non-null     float64
#  27  SSS         79 non-null     float64
#  28  FMB         82 non-null     int64
#  29  NAS         81 non-null     float64
#  30  EKB         81 non-null     float64
#  31  DKS         79 non-null     float64
#  32  IML         81 non-null     float64
#  33  XML         81 non-null     float64
#  34  MLS         79 non-null     float64
#  35  WMH         82 non-null     int64
#  36  GLS         81 non-null     float64
#  37  STB         81 non-null     float64
#  38  FRC         79 non-null     float64
#  39  FRS         79 non-null     float64
#  40  FRF         79 non-null     float64
#  41  PAC         79 non-null     float64
#  42  PAS         79 non-null     float64
#  43  PAF         79 non-null     float64
#  44  OCC         79 non-null     float64
#  45  OCS         79 non-null     float64
#  46  OCF         79 non-null     float64
#  47  FOL         82 non-null     int64
#  48  FOB         82 non-null     int64
#  49  NAR         81 non-null     float64
#  50  SSR         81 non-null     float64
#  51  PRR         75 non-null     float64
#  52  DKR         79 non-null     float64
#  53  ZOR         81 non-null     float64
#  54  FMR         82 non-null     int64
#  55  EKR         82 non-null     int64
#  56  ZMR         81 non-null     float64
#  57  AVR         67 non-null     float64
#  58  BRR         80 non-null     float64
#  59  VRR         79 non-null     float64
#  60  LAR         79 non-null     float64
#  61  OSR         82 non-null     int64
#  62  BAR         82 non-null     int64
#  63  MOW         74 non-null     float64
#  64  UFBR        82 non-null     int64
#  65  UFHT        61 non-null     float64
#  66  NAA         75 non-null     float64
#  67  PRA         75 non-null     float64
#  68  BAA         75 non-null     float64
#  69  NBA         79 non-null     float64
#  70  BBA         79 non-null     float64
#  71  BRA         79 non-null     float64
#  72  SSA         79 non-null     float64
#  73  NFA         81 non-null     float64
#  74  DKA         79 non-null     float64
#  75  NDA         72 non-null     float64
#  76  SIA         73 non-null     float64
#  77  FRA         79 non-null     float64
#  78  PAA         79 non-null     float64
#  79  OCA         79 non-null     float64
#  80  RFA         79 non-null     float64
#  81  RPA         79 non-null     float64
#  82  ROA         79 non-null     float64
#  83  BSA         76 non-null     float64
#  84  SBA         78 non-null     float64
#  85  SLA         79 non-null     float64
#  86  TBA         82 non-null     int64
#  87  Sex         82 non-null     object
#  88  Age         82 non-null     int64
# dtypes: float64(69), int64(18), object(2)
# memory usage: 57.7+ KB

# %% [markdown]
# ---

# %% [markdown]
# ## Remove traits

# %% [markdown]
# #### Remove traits with low intraobserver agreement (low Relative TEM)

# %%
# list of traits to be removed that have Relative TEM < 5

remove_traits
# Out:
#    Trait Name  n     TEM  Relative TEM
# 8         AUB  4  21.375      16.33238
# 38        FRF  4   3.375       8.51735
# 41        PAF  4   6.375      15.13353
# 44        OCF  4   2.250       5.29412
# 60        BAR  4   1.500      10.52632
# 74        SIA  4  35.000      32.55814

# %%
cranmet_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82 entries, 0 to 33
# Data columns (total 89 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SkelID      82 non-null     int64
#  1   Collection  82 non-null     object
#  2   GOL         78 non-null     float64
#  3   NOL         78 non-null     float64
#  4   BNL         81 non-null     float64
#  5   BBH         80 non-null     float64
#  6   XCB         82 non-null     int64
#  7   XFB         81 non-null     float64
#  8   WFB         82 non-null     int64
#  9   ZYB         82 non-null     int64
#  10  AUB         82 non-null     int64
#  11  ASB         73 non-null     float64
#  12  BPL         75 non-null     float64
#  13  NPH         74 non-null     float64
#  14  NLH         81 non-null     float64
#  15  JUB         82 non-null     int64
#  16  NLB         79 non-null     float64
#  17  MAB         60 non-null     float64
#  18  MAL         74 non-null     float64
#  19  MDH         82 non-null     int64
#  20  OBH         81 non-null     float64
#  21  OBB         79 non-null     float64
#  22  DKB         79 non-null     float64
#  23  NDS         72 non-null     float64
#  24  WNB         80 non-null     float64
#  25  SIS         73 non-null     float64
#  26  ZMB         80 non-null     float64
#  27  SSS         79 non-null     float64
#  28  FMB         82 non-null     int64
#  29  NAS         81 non-null     float64
#  30  EKB         81 non-null     float64
#  31  DKS         79 non-null     float64
#  32  IML         81 non-null     float64
#  33  XML         81 non-null     float64
#  34  MLS         79 non-null     float64
#  35  WMH         82 non-null     int64
#  36  GLS         81 non-null     float64
#  37  STB         81 non-null     float64
#  38  FRC         79 non-null     float64
#  39  FRS         79 non-null     float64
#  40  FRF         79 non-null     float64
#  41  PAC         79 non-null     float64
#  42  PAS         79 non-null     float64
#  43  PAF         79 non-null     float64
#  44  OCC         79 non-null     float64
#  45  OCS         79 non-null     float64
#  46  OCF         79 non-null     float64
#  47  FOL         82 non-null     int64
#  48  FOB         82 non-null     int64
#  49  NAR         81 non-null     float64
#  50  SSR         81 non-null     float64
#  51  PRR         75 non-null     float64
#  52  DKR         79 non-null     float64
#  53  ZOR         81 non-null     float64
#  54  FMR         82 non-null     int64
#  55  EKR         82 non-null     int64
#  56  ZMR         81 non-null     float64
#  57  AVR         67 non-null     float64
#  58  BRR         80 non-null     float64
#  59  VRR         79 non-null     float64
#  60  LAR         79 non-null     float64
#  61  OSR         82 non-null     int64
#  62  BAR         82 non-null     int64
#  63  MOW         74 non-null     float64
#  64  UFBR        82 non-null     int64
#  65  UFHT        61 non-null     float64
#  66  NAA         75 non-null     float64
#  67  PRA         75 non-null     float64
#  68  BAA         75 non-null     float64
#  69  NBA         79 non-null     float64
#  70  BBA         79 non-null     float64
#  71  BRA         79 non-null     float64
#  72  SSA         79 non-null     float64
#  73  NFA         81 non-null     float64
#  74  DKA         79 non-null     float64
#  75  NDA         72 non-null     float64
#  76  SIA         73 non-null     float64
#  77  FRA         79 non-null     float64
#  78  PAA         79 non-null     float64
#  79  OCA         79 non-null     float64
#  80  RFA         79 non-null     float64
#  81  RPA         79 non-null     float64
#  82  ROA         79 non-null     float64
#  83  BSA         76 non-null     float64
#  84  SBA         78 non-null     float64
#  85  SLA         79 non-null     float64
#  86  TBA         82 non-null     int64
#  87  Sex         82 non-null     object
#  88  Age         82 non-null     int64
# dtypes: float64(69), int64(18), object(2)
# memory usage: 57.7+ KB

# %%
## Remove traits with low intraobserver agreement:
# AUB (Biauricular breadth)
# FRF (Frontal fraction/Nasion-subtense fraction)
# PAF (Parietal fraction/Bregma-subtense fraction)
# OCF (Occipital fraction/Lambda-subtense fraction)
# BAR (Basion radius)
# SIA (Simotic angle)

del cranmet_merged['AUB']
del cranmet_merged['FRF']
del cranmet_merged['PAF']
del cranmet_merged['OCF']
del cranmet_merged['BAR']
del cranmet_merged['SIA']

# %%
cranmet_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82 entries, 0 to 33
# Data columns (total 83 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SkelID      82 non-null     int64
#  1   Collection  82 non-null     object
#  2   GOL         78 non-null     float64
#  3   NOL         78 non-null     float64
#  4   BNL         81 non-null     float64
#  5   BBH         80 non-null     float64
#  6   XCB         82 non-null     int64
#  7   XFB         81 non-null     float64
#  8   WFB         82 non-null     int64
#  9   ZYB         82 non-null     int64
#  10  ASB         73 non-null     float64
#  11  BPL         75 non-null     float64
#  12  NPH         74 non-null     float64
#  13  NLH         81 non-null     float64
#  14  JUB         82 non-null     int64
#  15  NLB         79 non-null     float64
#  16  MAB         60 non-null     float64
#  17  MAL         74 non-null     float64
#  18  MDH         82 non-null     int64
#  19  OBH         81 non-null     float64
#  20  OBB         79 non-null     float64
#  21  DKB         79 non-null     float64
#  22  NDS         72 non-null     float64
#  23  WNB         80 non-null     float64
#  24  SIS         73 non-null     float64
#  25  ZMB         80 non-null     float64
#  26  SSS         79 non-null     float64
#  27  FMB         82 non-null     int64
#  28  NAS         81 non-null     float64
#  29  EKB         81 non-null     float64
#  30  DKS         79 non-null     float64
#  31  IML         81 non-null     float64
#  32  XML         81 non-null     float64
#  33  MLS         79 non-null     float64
#  34  WMH         82 non-null     int64
#  35  GLS         81 non-null     float64
#  36  STB         81 non-null     float64
#  37  FRC         79 non-null     float64
#  38  FRS         79 non-null     float64
#  39  PAC         79 non-null     float64
#  40  PAS         79 non-null     float64
#  41  OCC         79 non-null     float64
#  42  OCS         79 non-null     float64
#  43  FOL         82 non-null     int64
#  44  FOB         82 non-null     int64
#  45  NAR         81 non-null     float64
#  46  SSR         81 non-null     float64
#  47  PRR         75 non-null     float64
#  48  DKR         79 non-null     float64
#  49  ZOR         81 non-null     float64
#  50  FMR         82 non-null     int64
#  51  EKR         82 non-null     int64
#  52  ZMR         81 non-null     float64
#  53  AVR         67 non-null     float64
#  54  BRR         80 non-null     float64
#  55  VRR         79 non-null     float64
#  56  LAR         79 non-null     float64
#  57  OSR         82 non-null     int64
#  58  MOW         74 non-null     float64
#  59  UFBR        82 non-null     int64
#  60  UFHT        61 non-null     float64
#  61  NAA         75 non-null     float64
#  62  PRA         75 non-null     float64
#  63  BAA         75 non-null     float64
#  64  NBA         79 non-null     float64
#  65  BBA         79 non-null     float64
#  66  BRA         79 non-null     float64
#  67  SSA         79 non-null     float64
#  68  NFA         81 non-null     float64
#  69  DKA         79 non-null     float64
#  70  NDA         72 non-null     float64
#  71  FRA         79 non-null     float64
#  72  PAA         79 non-null     float64
#  73  OCA         79 non-null     float64
#  74  RFA         79 non-null     float64
#  75  RPA         79 non-null     float64
#  76  ROA         79 non-null     float64
#  77  BSA         76 non-null     float64
#  78  SBA         78 non-null     float64
#  79  SLA         79 non-null     float64
#  80  TBA         82 non-null     int64
#  81  Sex         82 non-null     object
#  82  Age         82 non-null     int64
# dtypes: float64(65), int64(16), object(2)
# memory usage: 53.8+ KB

# %%
from google.colab import  drive
drive.mount('/drive')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
cranmet_merged.to_csv('/drive/My Drive/Colab Notebooks/Pre-statistical treatments/1_Observer error/cranmet_merged.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# ### **Output data files:**
# *   *cranmet_merged.csv*
# *   *cranmet_intraobserver_TEMoutput_results.csv*
# *   *cranmet_TEMresults_named.csv*
# *   The merged output file is in the (Intra)Observer Error folder and has had the traits removed with low IO agreement
# *   The *cranmet_TEMresults_named.csv* file is the *cranmet_TEMoutput.csv* with the trait codes AND trait names
